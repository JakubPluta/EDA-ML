# %%
import numpy as np
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
import requests

# %%
def extract_title(div):
	"""
	Wyszukanie informacji o tytule ogloszenia
	:param div:znacznik html w obrebie ktorego poszukujemy tytulu
	:return: tytul w formie stringa
	"""
	titles = 0
	for title in div.find_all(name='div', attrs={'class': 'title'}):
		for a in title.find_all(name='a', attrs={'data-tn-element': 'jobTitle'}):
			titles = (a['title'])
	return (titles)

# %%
def extract_company(div):
	"""
	Wyszukanie informacji o nazwie firmy
	:param div: znacznik html w obrebie ktorego poszukujemy nazwy firmy
	:return: nazwa firmy w formie stringa, lub informacja o jej nie znalezieniu
	"""
	companies=0
	for compa in div.find_all(name='div',attrs={'class':'sjcl'}):
		for comp in compa.find_all(name='span',attrs={'class':'company'}):
			if comp.find(name='a',attrs={'data-tn-element':'companyName'}):
				for company in comp.find_all(name='a',attrs={'data-tn-element':'companyName'}):
					companies=(company.text.strip())
			else:
				if(len(comp.text)>0):
					companies=(comp.text.strip())
				else:
					companies='company not found'
	return(companies)

# %%
def extract_location(div):
	"""
	Wyszukanie informacji o lokalizacji
	:param div: znacnzik html w obrebie ktorego poszukujemy lokalizacji
	:return: lokalizacja w formie stringa
	"""
	locations=0
	for location in div.find_all(name='div',attrs={'class':'sjcl'}):
		for loc in location.find_all(name='span',attrs={'class':'location'}):
			locations=loc.text.strip()
	return(locations)

# %%
def extract_summary(div):
	"""
	wyszukanie opisu stanowiska z ogloszenia
	:param div: znacznik html w obrebie ktorego poszukujemy opisu
	:return: opis w formie stringa
	"""
	summary=0
	for summ in div.find_all(name='div',attrs={'class','summary'}):
		summary=summ.text.strip()
	return(summary)

# %%
def extract_salary(div):
	"""
	Wyszukanie informacji o stawce w ogloszeniu
	:param div: znacnzik html w obrebie ktorego poszukujemy stawki
	:return: stawka w formie stringa
	"""
	salary=0
	if div.find('div',attrs={'class':'salarySnippet'}):
		for salar in div.find_all(name='div',attrs={'class':'salarySnippet'}):
			for span in salar.find_all(name='span',attrs={'class':'salary'}):
				salary=span.text.strip()
	else:
		salary='nothing found'
	return(salary)

# %%
def scrap_web(cities,max_results_per_city,name):
	"""
	Funkcja sluzaca do scrapowania informacji ze strony indeed.com
	:param cities: tabela miast w ktorych chcemy wyszukac ogloszenia (w przypadku miasta z 2 czlonami podajemy je z '+',np New+York)
	:param max_results_per_city: liczba okreslajaca ile maksymalnie ogloszen dla danego miasta chcemy przejrzec
	:param name: nazwa pliku csv do ktorego chcemy zapsiac nasze wyniki
	:return: none
	"""
	max_results_per_city=max_results_per_city
	cities=cities
	columns=['city','job_title','company_name','location','summary','salary']
	excel_name_=name
	sample_df=pd.DataFrame(columns=columns)
	for city in cities:
		for start in range(0,max_results_per_city,10):
			page=requests.get('https://www.indeed.com/jobs?q=data+scientist&l='+str(city)+'&start='+str(start))
			time.sleep(1)
			soup=BeautifulSoup(page.text,'lxml',from_encoding='utf-8')
			for div in soup.find_all(name='div',attrs={'class':'row'}):
				num=(len(sample_df)+1)
				job_post=[]
				job_post.append(city)
				job_post.append(extract_title(div))
				job_post.append(extract_company(div))
				job_post.append(extract_location(div))
				job_post.append(extract_summary(div))
				job_post.append(extract_salary(div))

				sample_df.loc[num]=job_post
		
	sample_df.to_csv(f'{name}.csv',encoding='utf-8')

# %%
cities=['New+York','Wrocław','Radom']
n=100
name='test'
scrap_web(cities,n,name)
# Out:
# D:\Anaconda\lib\site-packages\bs4\__init__.py:179: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
df=pd.read_csv('test.csv')

# %%
df
# Out:
#      Unnamed: 0      city                                        job_title  \
# 0             1  New+York  Data Scientist,Creator Marketplace – all levels
# 1             2  New+York                Data Scientist, Creator Marketing
# 2             3  New+York                              MODA Data Scientist
# 3             4  New+York                             Head of Data Science
# 4             5  New+York                            Junior Data Scientist
# 5             6  New+York                Data Scientist, Studios Analytics
# 6             7  New+York                 Data Scientist – Personalization
# 7             8  New+York                                   Data Scientist
# 8             9  New+York                             Data Scientist, Risk
# 9            10  New+York                                   Data Scientist
# 10           11  New+York                                   Data Scientist
# 11           12  New+York                                   Data Scientist
# 12           13  New+York                            Senior Data Scientist
# 13           14  New+York   Data Scientist, Partnerships Insights, YouTube
# 14           15  New+York                                   Data Scientist
# 15           16  New+York                                   Data Scientist
# 16           17  New+York                                   Data Scientist
# 17           18  New+York                                   Data Scientist
# 18           19  New+York                              MODA Data Scientist
# 19           20  New+York                                   Data Scientist
# 20           21  New+York                                 Data Scientist I
# 21           22  New+York                        Data Scientist, Detection
# 22           23  New+York                            Global Data Scientist
# 23           24  New+York             Data Scientist - Operations Research
# 24           25  New+York                Data Scientist, Content Promotion
# 25           26  New+York                    Data Analyst / Data Scientist
# 26           27  New+York                                   Data Scientist
# 27           28  New+York                                   Data Scientist
# 28           29  New+York                          Data Scientist- Lending
# 29           30  New+York                                   Data Scientist
# ..          ...       ...                                              ...
# 156         157     Radom                         Principal Data Scientist
# 157         158     Radom                      Operations Research Analyst
# 158         159     Radom                     Sr. Principal Data Scientist
# 159         160     Radom         Data Science/Operations Research Analyst
# 160         161     Radom                                                0
# 161         162     Radom                     Data Scientist - DISA Global
# 162         163     Radom                Data Scientist (Secret Clearance)
# 163         164     Radom                             Staff Data Scientist
# 164         165     Radom         Data Science/Operations Research Analyst
# 165         166     Radom                         Principal Data Scientist
# 166         167     Radom                      Operations Research Analyst
# 167         168     Radom                     Sr. Principal Data Scientist
# 168         169     Radom                                                0
# 169         170     Radom                     Data Scientist - DISA Global
# 170         171     Radom                Data Scientist (Secret Clearance)
# 171         172     Radom                             Staff Data Scientist
# 172         173     Radom                         Principal Data Scientist
# 173         174     Radom                     Sr. Principal Data Scientist
# 174         175     Radom         Data Science/Operations Research Analyst
# 175         176     Radom                      Operations Research Analyst
# 176         177     Radom                                                0
# 177         178     Radom                     Data Scientist - DISA Global
# 178         179     Radom              Data Analyst- Experienced Associate
# 179         180     Radom                             Staff Data Scientist
# 180         181     Radom                Data Scientist (Secret Clearance)
# 181         182     Radom                         Principal Data Scientist
# 182         183     Radom                     Sr. Principal Data Scientist
# 183         184     Radom                              Senior Data Analyst
# 184         185     Radom         Data Science/Operations Research Analyst
# 185         186     Radom                     Catastrophe Modeling Analyst
#
#                                    company_name  \
# 0                                       Spotify
# 1                                       Spotify
# 2    New York City DEPT OF INFO TECH & TELECOMM
# 3                                       EQUINOX
# 4                                        Viacom
# 5                                       Spotify
# 6                                       Spotify
# 7                                 1-800-Flowers
# 8                                        Square
# 9                                         AETNA
# 10                         Blackboard Insurance
# 11                                      Edelman
# 12                                          IBM
# 13                                      YouTube
# 14                                   Conde Nast
# 15                                        AETNA
# 16                                  Otis Wealth
# 17                                        VROOM
# 18   New York City DEPT OF INFO TECH & TELECOMM
# 19                           Macmillan Learning
# 20                                          AIG
# 21                                    White Ops
# 22                      Innovations for Poverty
# 23                New York City FIRE DEPARTMENT
# 24                                      Spotify
# 25                              Defined Clarity
# 26                         Blackboard Insurance
# 27                                      Ocrolus
# 28                                     Credibly
# 29                          New York University
# ..                                          ...
# 156                            Northrop Grumman
# 157                            Northrop Grumman
# 158                            Northrop Grumman
# 159                            Northrop Grumman
# 160                                           0
# 161                          Foxhole Technology
# 162              Logistics Management Institute
# 163                            Northrop Grumman
# 164                            Northrop Grumman
# 165                            Northrop Grumman
# 166                            Northrop Grumman
# 167                            Northrop Grumman
# 168                                           0
# 169                          Foxhole Technology
# 170              Logistics Management Institute
# 171                            Northrop Grumman
# 172                            Northrop Grumman
# 173                            Northrop Grumman
# 174                            Northrop Grumman
# 175                            Northrop Grumman
# 176                                           0
# 177                          Foxhole Technology
# 178                                  Guidehouse
# 179                            Northrop Grumman
# 180              Logistics Management Institute
# 181                            Northrop Grumman
# 182                            Northrop Grumman
# 183                 Advanced Core Concepts, LLC
# 184                            Northrop Grumman
# 185                              AXIS Insurance
#
#                                          location  \
# 0               New York, NY 10011 (Chelsea area)
# 1               New York, NY 10011 (Chelsea area)
# 2                                   Manhattan, NY
# 3                                    New York, NY
# 4                              New York, NY 10036
# 5               New York, NY 10011 (Chelsea area)
# 6               New York, NY 10011 (Chelsea area)
# 7                           Carle Place, NY 11514
# 8    New York, NY 10032 (Washington Heights area)
# 9              New York, NY 10016 (Gramercy area)
# 10   New York, NY 10271 (Financial District area)
# 11                             New York, NY 10036
# 12      New York, NY 10002 (Lower East Side area)
# 13                                   New York, NY
# 14                             New York, NY 10048
# 15             New York, NY 10016 (Gramercy area)
# 16                                   New York, NY
# 17                                   New York, NY
# 18                                  Manhattan, NY
# 19                                   New York, NY
# 20                                   New York, NY
# 21                                   New York, NY
# 22                                   New York, NY
# 23                                   Brooklyn, NY
# 24              New York, NY 10011 (Chelsea area)
# 25                                   New York, NY
# 26   New York, NY 10271 (Financial District area)
# 27                                   New York, NY
# 28                                   New York, NY
# 29                                   New York, NY
# ..                                            ...
# 156                           Scott AFB, IL 62225
# 157                           Scott AFB, IL 62225
# 158                           Scott AFB, IL 62225
# 159                           Scott AFB, IL 62225
# 160                                             0
# 161                                 Scott AFB, IL
# 162                                 Scott AFB, IL
# 163                           Scott AFB, IL 62225
# 164                           Scott AFB, IL 62225
# 165                           Scott AFB, IL 62225
# 166                           Scott AFB, IL 62225
# 167                           Scott AFB, IL 62225
# 168                                             0
# 169                                 Scott AFB, IL
# 170                                 Scott AFB, IL
# 171                           Scott AFB, IL 62225
# 172                           Scott AFB, IL 62225
# 173                           Scott AFB, IL 62225
# 174                           Scott AFB, IL 62225
# 175                           Scott AFB, IL 62225
# 176                                             0
# 177                                 Scott AFB, IL
# 178                                 Scott AFB, IL
# 179                           Scott AFB, IL 62225
# 180                                 Scott AFB, IL
# 181                           Scott AFB, IL 62225
# 182                           Scott AFB, IL 62225
# 183                                 Scott AFB, IL
# 184                           Scott AFB, IL 62225
# 185                                University, IL
#
#                                                summary  \
# 0    The Creator Product Insights Team is a thrivin...
# 1    The Creator Product Insights Team is a thrivin...
# 2    MODA seeks a Data Scientist to join a diverse ...
# 3    Collaborate hands on with business, data scien...
# 4    Familiarity with statistical modeling and mach...
# 5    2+ years (5+ years for senior role) of relevan...
# 6    Contribute to the development of the Product I...
# 7    This individual will manage one or more analys...
# 8    Experience developing and deploying machine le...
# 9    Aetna's Provider & Network Analytics team is f...
# 10   Scientific expertise and applied experience in...
# 11   Help lead day to day project execution includi...
# 12   Utilize Machine Learning/Statistics, Spark, Py...
# 13   The YouTube Insights, Infrastructure, and Tool...
# 14   Work with both management and organizational p...
# 15   Aetna's Provider & Network Analytics team is f...
# 16   Inspired by Buffer’s salary transparency, ever...
# 17   To help out, we are looking for experienced Da...
# 18   MODA seeks a Data Scientist to join a diverse ...
# 19   Master's or PhD in data analytics, machine lea...
# 20   Data Scientists collaborate with AIG’s Life an...
# 21   Interest in Data Visualization. The Data Intel...
# 22   Demonstrated statistical programming and data ...
# 23   For Assignment Level I (only physical, biologi...
# 24   We require a strong Data Scientist who can lea...
# 25   Must be able to write SQL queries and must hav...
# 26   Advanced programming skills in Python and/or R...
# 27   Experience working with Data Scientists and Da...
# 28   Strong applied statistics and machine learning...
# 29   The Public Safety Lab at New York University i...
# ..                                                 ...
# 156  Creating data mining architectures/models/prot...
# 157  Master's degree from an accredited college or ...
# 158  Research and develop statistical learning mode...
# 159  Research and develop statistical learning mode...
# 160                                                  0
# 161  Perform data mining, data cleaning, data explo...
# 162  Research and develop statistical learning mode...
# 163  Interpret large amounts of data with advanced ...
# 164  Research and develop statistical learning mode...
# 165  Research and develop statistical learning mode...
# 166  Master's degree from an accredited college or ...
# 167  Research and develop statistical learning mode...
# 168                                                  0
# 169  Perform data mining, data cleaning, data explo...
# 170  Research and develop statistical learning mode...
# 171  Interpret large amounts of data with advanced ...
# 172  Creating data mining architectures/models/prot...
# 173  Research and develop statistical learning mode...
# 174  Research and develop statistical learning mode...
# 175  Master's degree from an accredited college or ...
# 176                                                  0
# 177  Findings presented may include insights from d...
# 178  Advanced analytics techniques (regression, sim...
# 179  Interpret large amounts of data with advanced ...
# 180  Interpret large amounts of data with advanced ...
# 181  Requires strong statistical and data visualiza...
# 182  Interpret large amounts of data with advanced ...
# 183  Understanding of data modeling and database de...
# 184  Interpret large amounts of data with advanced ...
# 185  Required Skills, Qualifications & Experience:....
#
#                                           salary
# 0                                  nothing found
# 1                                  nothing found
# 2                       $52,524 - $79,000 a year
# 3                                  nothing found
# 4                                  nothing found
# 5                                  nothing found
# 6                                  nothing found
# 7                                  nothing found
# 8                                  nothing found
# 9                                  nothing found
# 10      $106,000 - $156,000 a year (Indeed est.)
# 11       $96,000 - $141,000 a year (Indeed est.)
# 12                                 nothing found
# 13       $97,000 - $144,000 a year (Indeed est.)
# 14       $94,000 - $139,000 a year (Indeed est.)
# 15       $94,000 - $139,000 a year (Indeed est.)
# 16                     $75,000 - $125,000 a year
# 17      $105,000 - $155,000 a year (Indeed est.)
# 18                      $52,524 - $79,000 a year
# 19       $95,000 - $140,000 a year (Indeed est.)
# 20                                 nothing found
# 21    Similar jobs pay $93,000 - $137,000 a year
# 22    Similar jobs pay $90,000 - $132,000 a year
# 23                      $82,008 - $94,309 a year
# 24    Similar jobs pay $93,000 - $137,000 a year
# 25                             $65 - $75 an hour
# 26   Similar jobs pay $106,000 - $156,000 a year
# 27   Similar jobs pay $113,000 - $167,000 a year
# 28   Similar jobs pay $115,000 - $169,000 a year
# 29    Similar jobs pay $73,000 - $108,000 a year
# ..                                           ...
# 156                                nothing found
# 157                                nothing found
# 158                                nothing found
# 159                                nothing found
# 160                                nothing found
# 161   Similar jobs pay $96,000 - $142,000 a year
# 162  Similar jobs pay $102,000 - $151,000 a year
# 163   Similar jobs pay $97,000 - $143,000 a year
# 164   Similar jobs pay $88,000 - $129,000 a year
# 165                                nothing found
# 166                                nothing found
# 167                                nothing found
# 168                                nothing found
# 169   Similar jobs pay $96,000 - $142,000 a year
# 170  Similar jobs pay $102,000 - $151,000 a year
# 171   Similar jobs pay $97,000 - $143,000 a year
# 172                                nothing found
# 173                                nothing found
# 174   Similar jobs pay $88,000 - $129,000 a year
# 175                                nothing found
# 176                                nothing found
# 177                                nothing found
# 178                                nothing found
# 179                                nothing found
# 180                                nothing found
# 181                                nothing found
# 182                                nothing found
# 183                                nothing found
# 184                                nothing found
# 185                                nothing found
#
# [186 rows x 7 columns]
