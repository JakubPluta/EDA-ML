# %%
import requests as req
import bs4
from bs4 import BeautifulSoup as BS
import urllib
import pandas as pd
import numpy as np
import re
from urllib.request import urlopen
pd.set_option('max_colwidth',500)

# %%
URL = "http://www.indeed.com/jobs?q=Python&l=New+York&start=10"
req = urlopen(URL).read()
soup = BS(req, "html.parser")
city = ''
start = ''
jobs = ''
url_tmp = f"http://www.indeed.com/jobs?q={jobs}&l={city}&start={start}"

# %%
USA_Cities = ['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Seattle', 
    'Los+Angeles', 'Philadelphia', 'Atlanta', 'Dallas', 'Pittsburgh', 
    'Portland', 'Phoenix', 'Denver', 'Houston', 'Miami', 'washington+dc', 'boston', 'new+orleans', 
         'charlotte']

# %%
def make_database(tech='Python',cities=USA_Cities,limit=30):
    data = pd.DataFrame(columns=["location", 'company', 'job_title', 'salary','summary','job_link','company_link'])
    for city in cities:
        for s in range(0,limit,10):
            base_url = 'http://www.indeed.com'
            u = f"http://www.indeed.com/jobs?q={tech}&l={tech}&start={s}"
            #print(u)
            reqs = urlopen(URL).read()
            soups = BS(reqs, "html.parser")
            for x in soups.find_all('div', attrs = {'class':'row'}):
                try:
                    company = x.find('span', attrs = {'class':'company'}).text.strip()
                except:
                    company = 'NA'
                try:
                    company_url = (f"{base_url}{x.a['href']}")
                except:
                    company_url = 'NA'
                try:
                    location = x.find(name='span',attrs={'class':'location'}).text.strip()
                except:
                    location = 'NA'                              
                try:
                    job = x.find(name='a',attrs={'data-tn-element':'jobTitle'}).text.strip()
                except:
                    job = 'NA'                         
                try:
                    temp_job = x.find(name='a',attrs={'data-tn-element':'jobTitle'})['href']
                    job_link = (f"{base_url}{temp_job}")                   
                except:
                    job_link = 'NA'

                try:
                    salary = x.find(name='span',attrs={'class' : 'salary no-wrap'}).text.strip()
                except:
                    salary = 'NA'                
                try:
                    summary = x.find(name='div',attrs={'class':'summary'}).text.strip()
                except:
                    summary = 'NA'

                data = data.append({"location":location, 
                                    'company':company, 
                                    'job_title':job, 
                                    'salary':salary,
                                    'summary':summary,
                                    'job_link':job_link,
                                    'company_link':company_url
                                   },ignore_index=True)
        return data

# %%
x = make_database(tech='Java',cities=USA_Cities,limit=30)

# %%
x.head()
# Out:
#                             location              company  \
# 0                 New York, NY 10036      Bank of America
# 1                       New York, NY  Columbia University
# 2                       New York, NY            okyte Inc
# 3  New York, NY 10018 (Clinton area)            BlindData
# 4                       New York, NY               Huxley
#
#                             job_title                      salary  \
# 0                    Python Developer                          NA
# 1          Technician A - CCTI (HIMC)                 $702 a week
# 2         Python full stack developer    $60,000 - $90,000 a year
# 3            Python Software Engineer  $120,000 - $200,000 a year
# 4  NYC - 170k - Python Dev Hedge Fund  $120,000 - $170,000 a year
#
#                                                                                                                                                          summary  \
# 0                                         Responsible for developing, enhancing, modifying and/or maintaining applications in the Global Markets environment....
# 1  Working in the Human Immune Monitoring Core (HIMC) within the Columbia Center for Translational Immunology (CCTI), the Technician A will help maintain and...
# 2                                We are looking for a Python Web Developer responsible for managing the interchange of data between the server and the users....
# 3                 BlindData is calling all talented software engineers to test yourself against the best engineers from Google and MIT. It’s as easy as that!...
# 4                                      This Hedge Fund is looking for a Python Developer with Agile experience coming in with a min of 3 years of experience....
#
#                                                                                                                  job_link  \
# 0                                           http://www.indeed.com/rc/clk?jk=2d6a1defaa007a25&fccid=5bd99dfa21c8a490&vjs=3
# 1                                           http://www.indeed.com/rc/clk?jk=7044ab29977c401a&fccid=bd976cc171c690e0&vjs=3
# 2  http://www.indeed.com/company/okyte-Inc/jobs/Python-Full-Stack-Developer-27f02304661195c0?fccid=e96b4eb3ae31f4f2&vjs=3
# 3     http://www.indeed.com/company/BlindData/jobs/Python-Software-Engineer-cd11f2401582b721?fccid=55962a85574fa94f&vjs=3
# 4                             http://www.indeed.com/company/Huxley/jobs/Nyc-a02b9f2ce4acbe5f?fccid=f74925bad7a7b5a8&vjs=3
#
#                                                                                                              company_link
# 0                                           http://www.indeed.com/rc/clk?jk=2d6a1defaa007a25&fccid=5bd99dfa21c8a490&vjs=3
# 1                                           http://www.indeed.com/rc/clk?jk=7044ab29977c401a&fccid=bd976cc171c690e0&vjs=3
# 2  http://www.indeed.com/company/okyte-Inc/jobs/Python-Full-Stack-Developer-27f02304661195c0?fccid=e96b4eb3ae31f4f2&vjs=3
# 3     http://www.indeed.com/company/BlindData/jobs/Python-Software-Engineer-cd11f2401582b721?fccid=55962a85574fa94f&vjs=3
# 4                             http://www.indeed.com/company/Huxley/jobs/Nyc-a02b9f2ce4acbe5f?fccid=f74925bad7a7b5a8&vjs=3
