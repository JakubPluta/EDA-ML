# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib 
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontManager
import matplotlib.style as style
from matplotlib import cm
#sns.set_context('paper')

# %%
# Load Files
b15 = pd.read_csv('Boston_Marathon\m2015.csv')
b16 = pd.read_csv('Boston_Marathon\m2016.csv')
b17 = pd.read_csv('Boston_Marathon\m2017.csv')

# %%
b15['Year'] = 2015
b16['Year'] = 2016
b17['Year'] = 2017

# %%
data = pd.concat([b15,b16,b17],ignore_index=True,sort=False)
data.set_index('Name',inplace=True)
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.head()
# Out:
#                       Bib  Age M/F         City State Country Citizen  \
# Name
# Desisa, Lelisa          3   25   M         Ambo   NaN     ETH     NaN
# Tsegay, Yemane Adhane   4   30   M  Addis Ababa   NaN     ETH     NaN
# Chebet, Wilson          8   29   M     Marakwet   NaN     KEN     NaN
# Kipyego, Bernard       11   28   M      Eldoret   NaN     KEN     NaN
# Korir, Wesley          10   32   M       Kitale   NaN     KEN     NaN
#
#                       Unnamed: 9       5K      10K  ...      35K      40K  \
# Name                                                ...
# Desisa, Lelisa               NaN  0:14:43  0:29:43  ...  1:47:59  2:02:39
# Tsegay, Yemane Adhane        NaN  0:14:43  0:29:43  ...  1:47:59  2:02:42
# Chebet, Wilson               NaN  0:14:43  0:29:43  ...  1:47:59  2:03:01
# Kipyego, Bernard             NaN  0:14:43  0:29:44  ...  1:48:03  2:03:47
# Korir, Wesley                NaN  0:14:43  0:29:44  ...  1:47:59  2:03:27
#
#                           Pace Proj Time Official Time Overall Gender  \
# Name
# Desisa, Lelisa         0:04:56         -       2:09:17       1      1
# Tsegay, Yemane Adhane  0:04:58         -       2:09:48       2      2
# Chebet, Wilson         0:04:59         -       2:10:22       3      3
# Kipyego, Bernard       0:05:00         -       2:10:47       4      4
# Korir, Wesley          0:05:00         -       2:10:49       5      5
#
#                       Division  Year Unnamed: 8
# Name
# Desisa, Lelisa               1  2015        NaN
# Tsegay, Yemane Adhane        2  2015        NaN
# Chebet, Wilson               3  2015        NaN
# Kipyego, Bernard             4  2015        NaN
# Korir, Wesley                5  2015        NaN
#
# [5 rows x 25 columns]

# %%
data.shape
# Out:
# (79638, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79638 entries, Desisa, Lelisa to Rigsby, Scott
# Data columns (total 25 columns):
# Bib              79638 non-null object
# Age              79638 non-null int64
# M/F              79638 non-null object
# City             79637 non-null object
# State            70645 non-null object
# Country          79638 non-null object
# Citizen          3440 non-null object
# Unnamed: 9       158 non-null object
# 5K               79638 non-null object
# 10K              79638 non-null object
# 15K              79638 non-null object
# 20K              79638 non-null object
# Half             79638 non-null object
# 25K              79638 non-null object
# 30K              79638 non-null object
# 35K              79638 non-null object
# 40K              79638 non-null object
# Pace             79638 non-null object
# Proj Time        79638 non-null object
# Official Time    79638 non-null object
# Overall          79638 non-null int64
# Gender           79638 non-null int64
# Division         79638 non-null int64
# Year             79638 non-null int64
# Unnamed: 8       83 non-null object
# dtypes: int64(5), object(20)
# memory usage: 15.8+ MB

# %%
def isnull(data):
    nulls = pd.concat([data.isnull().sum().to_frame(),data.isnull().sum().to_frame()/data.shape[0]],axis=1)
    nulls.columns = ['Number','Pct']
    nulls = nulls.sort_values(by='Number',ascending=False)
    nulls = nulls[nulls['Number']>0]
    return nulls
    
fonts = [f.name for f in matplotlib.font_manager.fontManager.afmlist]   

def get_Colors():
    colorname, colorid = [],[]
    for name, hex in matplotlib.colors.cnames.items():
        colorname.append(name)
        colorid.append(hex)
    return list(zip(colorname,colorid))

def annotate(ax,s="%.4f"):
    for p in ax.patches:
        ax.annotate(s % p.get_height(), 
                 (p.get_x() + p.get_width() / 2,
                  p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
def despine(rot=0):
    sns.despine(left=True)
    plt.xticks(rotation = rot);
    plt.xlabel('');
    plt.ylabel('');
    
    
def age_group(x):
    if x > 0 and x < 20:
        return '18-20'
    elif  x < 30:
        return '20-30'
    elif  x < 40:
        return '30-40'
    elif  x < 50:
        return '40-50'
    else:
        return '50-84'

# %%
nulls = isnull(data)
nulls.drop('Number',axis=1).reset_index()
# Out:
#         index       Pct
# 0  Unnamed: 8  0.998958
# 1  Unnamed: 9  0.998016
# 2     Citizen  0.956805
# 3       State  0.112923
# 4        City  0.000013

# %%
f,ax = plt.subplots(figsize=(15,5))
n1 = sns.barplot(x='index',y='Pct',data=nulls.drop('Number',axis=1).reset_index(),palette=
           'Blues_d')
despine()
annotate(ax=n1)
n1.set_ylim([0,1.2])
n1.set_title('Null values in dataset',fontsize=15,pad=20);

# %%
data = data.drop(['Unnamed: 8','Unnamed: 9','Citizen'],axis=1) # Drop Nulls
data.iloc[:, 6:18] = data.iloc[:, 6:18].apply(pd.to_timedelta) # Convert time columns from object to pd time format
data.drop('Proj Time',axis=1,inplace=True) # drop this columns beacuse there are only 0
data['Age Grouped'] = data['Age'].apply(lambda x: age_group(x))
data['Official Time Minutes'] = data['Official Time'].apply(lambda x: x.total_seconds()/60)

# %%
data.describe()
# Out:
#                 Age                      5K                     10K  \
# count  79638.000000                   79638                   79638
# mean      42.415166  0 days 00:25:23.000326  0 days 00:50:51.631520
# std       11.355453  0 days 00:04:11.553378  0 days 00:08:13.351595
# min       18.000000         0 days 00:00:00         0 days 00:00:00
# 25%       34.000000         0 days 00:22:33         0 days 00:45:09
# 50%       42.000000         0 days 00:24:56         0 days 00:49:51
# 75%       50.000000         0 days 00:27:34         0 days 00:55:12
# max       84.000000         0 days 00:55:50         0 days 01:47:16
#
#                           15K                     20K                    Half  \
# count                   79638                   79638                   79638
# mean   0 days 01:16:47.095042  0 days 01:43:26.880860  0 days 01:49:14.119503
# std    0 days 00:12:25.000654  0 days 00:17:18.860885  0 days 00:18:12.861931
# min           0 days 00:00:00         0 days 00:00:00         0 days 00:00:00
# 25%           0 days 01:08:04         0 days 01:31:33         0 days 01:36:39
# 50%           0 days 01:15:07         0 days 01:41:02         0 days 01:46:38
# 75%           0 days 01:23:16         0 days 01:52:12         0 days 01:58:27
# max           0 days 02:41:45         0 days 04:29:40         0 days 04:47:17
#
#                           25K                     30K                     35K  \
# count                   79638                   79638                   79638
# mean   0 days 02:10:49.505864  0 days 02:39:44.614480  0 days 03:09:57.422486
# std    0 days 00:22:31.555723  0 days 00:28:19.993863  0 days 00:34:17.595018
# min           0 days 00:00:00         0 days 00:00:00         0 days 00:00:00
# 25%           0 days 01:55:26         0 days 02:20:27         0 days 02:46:34
# 50%           0 days 02:07:27         0 days 02:35:24         0 days 03:04:36
# 75%           0 days 02:22:06         0 days 02:54:05         0 days 03:27:42
# max           0 days 04:36:06         0 days 07:36:38         0 days 06:51:31
#
#                           40K                    Pace           Official Time  \
# count                   79638                   79638                   79638
# mean   0 days 03:39:58.872422  0 days 00:08:54.086529  0 days 03:53:09.929166
# std    0 days 00:39:51.034077  0 days 00:01:35.090340  0 days 00:41:32.272068
# min           0 days 00:00:00         0 days 00:04:56         0 days 02:09:17
# 25%           0 days 03:12:48         0 days 00:07:48         0 days 03:24:18
# 50%           0 days 03:33:48         0 days 00:08:39         0 days 03:46:32
# 75%           0 days 04:01:07         0 days 00:09:45         0 days 04:15:25
# max           0 days 07:59:12         0 days 00:24:30         0 days 10:30:23
#
#             Overall        Gender      Division          Year  \
# count  79638.000000  79638.000000  79638.000000  79638.000000
# mean   13273.683417   6693.365064   1618.782792   2015.997639
# std     7663.512720   3927.594786   1448.369424      0.815852
# min        1.000000      1.000000      1.000000   2015.000000
# 25%     6637.250000   3319.000000    510.000000   2015.000000
# 50%    13273.500000   6637.000000   1179.500000   2016.000000
# 75%    19910.000000   9955.000000   2219.000000   2017.000000
# max    26629.000000  14581.000000   6004.000000   2017.000000
#
#        Official Time Minutes
# count           79638.000000
# mean              233.165486
# std                41.537868
# min               129.283333
# 25%               204.300000
# 50%               226.533333
# 75%               255.416667
# max               630.383333

# %%
ym = data.groupby('Year')['Bib'].count().to_frame().reset_index()
ym
# Out:
#    Year    Bib
# 0  2015  26598
# 1  2016  26630
# 2  2017  26410

# %%
ym2 = data.groupby(['Year','M/F'])['Bib'].count().to_frame().reset_index()
ym2
# Out:
#    Year M/F    Bib
# 0  2015   F  12017
# 1  2015   M  14581
# 2  2016   F  12167
# 3  2016   M  14463
# 4  2017   F  11972
# 5  2017   M  14438

# %%
f,ax = plt.subplots(1,2,figsize=(15,5))
y1 = sns.barplot(x='Year',y='Bib',data=ym,
           palette=['#0B486B','#79BD9A','#B5838D'],ax=ax[0])
annotate(ax=y1,s="%.0f")
y1.set_ylabel('')
y1.set_ylim([25798,26830])
y1.set_title('Marathon Runners in 2015-2017',fontsize=15,pad=20);

y2 = sns.barplot(x='Year',y='Bib',data=ym2,hue='M/F',
           palette=['#FE938C','#3A506B'],ax=ax[1])
annotate(ax=y2,s="%.0f")
y2.set_ylabel('')
y2.set_ylim([10000,15500])
y2.set_title('Marathon Runners in 2015-2017 by Gender',fontsize=15,pad=20);

# %%
bins1 = round((data[data['M/F']=='F']['Age'].max() - data[data['M/F']=='F']['Age'].min()))
bins2 = data[data['M/F']=='M']['Age'].max() - data[data['M/F']=='M']['Age'].min()
f,ax = plt.subplots(1,1,figsize=(15,5))
# sns.distplot(data[data['M/F']=='F']['Age'],color='#FE938C',bins=bins1)
# sns.distplot(data[data['M/F']=='M']['Age'],color='#3A506B',bins=bins2)
plt.hist(data[data['M/F']=='F']['Age'],color='#FE938C',alpha=0.8,bins=bins1);
plt.hist(data[data['M/F']=='M']['Age'],color='#3A506B',alpha=0.65,bins=bins2);
despine()
plt.suptitle('Distribution of Marathon Runners By Age',fontsize=15);

# %%
y1,y2,y3 = data[data['Year']==2015],data[data['Year']==2016],data[data['Year']==2017]
f,ax = plt.subplots(3,1,figsize=(15,18))
a1 = sns.countplot('Age',data=y1, palette=['#c55572'],ax=ax[0])
a1.set_title('2015 Marathon Runners by Age')
a1.set_ylabel('');
a1.set_xlabel('');
a2 = sns.countplot('Age',data=y2, palette=['#0B486B'],ax=ax[1])
a2.set_title('2016 Marathon Runners by Age')
a2.set_ylabel('');
a2.set_xlabel('');
a3 = sns.countplot('Age',data=y3, palette=['#00A572'],ax=ax[2])
a3.set_title('2017 Marathon Runners by Age')
a3.set_ylabel('');
a3.set_xlabel('');
despine()

# %%
cm = sns.light_palette("#c55572", as_cmap=True)
data.groupby(['M/F','Year'])['Age'].describe().style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col0 {
#             background-color:  #f8eaed;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col1 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col2 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col3 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col4 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col5 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col6 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col7 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row1_col0 {
#             background-color:  #f5e1e6;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row1_col1 {
#             background-color:  #f4e0e5;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row1_col2 {
#             background-color:  #f3dbe1;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row1_col3 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row1_col4 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row1_col5 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row1_col6 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row1_col7 {
#             background-color:  #dfa0b0;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row2_col0 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row2_col1 {
#             background-color:  #f4dee4;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row2_col2 {
#             background-color:  #edcbd4;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row2_col3 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row2_col4 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row2_col5 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row2_col6 {
#             background-color:  #f0d3db;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row2_col7 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row3_col0 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row3_col1 {
#             background-color:  #c9617c;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row3_col2 {
#             background-color:  #c85e79;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row3_col3 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row3_col4 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row3_col5 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row3_col6 {
#             background-color:  #cd6e87;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row3_col7 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row4_col0 {
#             background-color:  #c75c77;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row4_col1 {
#             background-color:  #c55673;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row4_col2 {
#             background-color:  #c75a76;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row4_col3 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row4_col4 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row4_col5 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row4_col6 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row4_col7 {
#             background-color:  #dfa0b0;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row5_col0 {
#             background-color:  #c85d79;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row5_col1 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row5_col2 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row5_col3 {
#             background-color:  #f9ecef;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row5_col4 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row5_col5 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row5_col6 {
#             background-color:  #c55572;
#             color:  #000000;
#         }    #T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row5_col7 {
#             background-color:  #dfa0b0;
#             color:  #000000;
#         }</style><table id="T_f5ae6c22_d57a_11e9_812e_7085c28d62d7" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr>    <tr>        <th class="index_name level0" >M/F</th>        <th class="index_name level1" >Year</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5ae6c22_d57a_11e9_812e_7085c28d62d7level0_row0" class="row_heading level0 row0" rowspan=3>F</th>
#                         <th id="T_f5ae6c22_d57a_11e9_812e_7085c28d62d7level1_row0" class="row_heading level1 row0" >2015</th>
#                         <td id="T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col0" class="data row0 col0" >12017</td>
#                         <td id="T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col1" class="data row0 col1" >39.4618</td>
#                         <td id="T_f5ae6c22_d57a_11e9_812e_7085c28d62d7row0_col2" class="data row0 col2" >10.471

# %%
m = data[data['M/F']=='M']
f = data[data['M/F']=='F']
oldf = f.loc[f['Age'].idxmax()].head(1) # oldest runner Female in 2015,2016,2017
oldm = m.loc[m['Age'].idxmax()].head(1) # oldest runner Male in 2015,2016
pd.concat([oldf,oldm])
# Oldest runner by gender
# Out:
#                      Bib  Age M/F        City State Country       5K      10K  \
# Name
# Beiers, Katherine  25555   82   F  Santa Cruz    CA     USA 00:36:54 01:14:34
# Wilson, Harold     24564   82   M       Tyler    TX     USA 00:28:17 00:56:47
#
#                        15K      20K  ...      35K      40K     Pace  \
# Name                                 ...
# Beiers, Katherine 01:54:54 02:36:39  ... 04:49:32 05:33:24 00:13:30
# Wilson, Harold    01:25:21 01:55:29  ... 03:31:53 04:04:23 00:09:51
#
#                   Official Time Overall Gender Division  Year  Age Grouped  \
# Name
# Beiers, Katherine      05:53:40   26411  11923        1  2015        50-84
# Wilson, Harold         04:18:00   21626  12387        1  2015        50-84
#
#                    Official Time Minutes
# Name
# Beiers, Katherine             353.666667
# Wilson, Harold                258.000000
#
# [2 rows x 23 columns]

# %%
## Youngest Males
#data[data['M/F']=='M'].sort_values(by=['Age','Year'],ascending=True).head()
## Youngerst Females
# data[data['M/F']=='F'].sort_values(by=['Age','Year'],ascending=True).head()

# %%
## Oldest Males & Females
of = y3[y3['M/F']=='F']['Age'].nlargest(3).to_frame()
om = y3[y3['M/F']=='M']['Age'].nlargest(3).to_frame()
om['Gender'] = 'Male'
of['Gender'] = 'Female'
yf = y3[y3['M/F']=='F']['Age'].nsmallest(3).to_frame()
ym = y3[y3['M/F']=='M']['Age'].nsmallest(3).to_frame()
ym['Gender'] = 'Male'
yf['Gender'] = 'Female'
pd.concat([of,om])
# Out:
#                      Age  Gender
# Name
# Beiers, Katherine     84  Female
# Bardin, Dorothy       77  Female
# Rigney, Hansi L.      75  Female
# Yoo, Jack             83    Male
# Shimojou, Michiharu   81    Male
# Roake, Samuel C.      81    Male

# %%
## Youngest Males & Females
pd.concat([yf,ym])
# Out:
#                     Age  Gender
# Name
# Rucker, Alyssa       18  Female
# Pohl, Elizabeth S.   18  Female
# Georgaklis, Sofia    18  Female
# Eastmond, Riley J    18    Male
# Fickes, Ben          18    Male
# Moore, Ryan D        18    Male

# %%
f,ax = plt.subplots(1,2,figsize=(16,6))
b1 = sns.boxplot(y='Age',hue = 'M/F',x='Year',data=data,linewidth=0.75,width=0.5, palette=['#3A506B','#FE938C'],ax=ax[0])
despine()
b1.set_title('Distribution of Age by Gender')
my_circle=plt.Circle( (0,0), 0.83, color='white')
names=['Male','Female']
size=data['M/F'].value_counts().tolist()
plt.pie(size, labels=names, colors=['#3A506B','#FE938C'],autopct='%1.2f%%',startangle=35)
p=plt.gcf()
p.gca().add_artist(my_circle);
plt.setp(plt.gcf().get_axes(), xlabel='', ylabel='');
plt.title('Marathon runners by gender');

# %%
g2=pd.DataFrame(data.groupby(['Year','M/F','Age Grouped'])['Bib'].count())
g3=g2.pivot_table(values='Bib',index=['M/F','Year'], columns='Age Grouped')
df_gr = pd.crosstab(data['Age Grouped'],data['M/F']).apply(lambda x: (x/x.sum()) * 100 , axis=1)
f,ax = plt.subplots(1,2,figsize=(15,5))
g04 = g3.plot(kind='barh',stacked=True,ax=ax[0]);
g04.legend(loc='best', bbox_to_anchor=(0.5, 0., 0.5, 0.5));
g4 = df_gr.plot(kind = "bar", stacked = True, color = ['#3A506B','#FE938C']
                       ,ax=ax[1])
g4.legend(bbox_to_anchor = (1.15, 1));
plt.suptitle('Age Distribution by Gender',fontsize=15);

# %%
data.groupby(['M/F','Year'])['Age'].describe()
# Out:
#             count       mean        std   min   25%   50%   75%   max
# M/F Year
# F   2015  12017.0  39.461846  10.471137  18.0  31.0  40.0  47.0  82.0
#     2016  12167.0  39.896030  10.590690  18.0  31.0  40.0  47.0  83.0
#     2017  11972.0  39.952974  10.703554  18.0  31.0  40.0  48.0  84.0
# M   2015  14581.0  44.356011  11.468329  18.0  36.0  45.0  52.0  82.0
#     2016  14463.0  44.716449  11.495371  18.0  36.0  45.0  53.0  83.0
#     2017  14438.0  44.772475  11.533255  18.0  36.0  45.0  53.0  83.0

# %% [markdown]
# **We can see that 55% of marathon runners were males and 45% females. We can also notice that average age of runner in male group was around 45 and in female group it was 40. So we female runners were younger than males.**
# **We can also notice that with age rises ratio male/female rises**

# %%
win2015 = data[data['Year']==2015][['Age','M/F','Official Time Minutes']].sort_values(by='Official Time Minutes').head(5)
win2016 = data[data['Year']==2016][['Age','M/F','Official Time Minutes']].sort_values(by='Official Time Minutes').head(5)
win2017 = data[data['Year']==2017][['Age','M/F','Official Time Minutes']].sort_values(by='Official Time Minutes').head(5)

# %%
f,ax = plt.subplots(1,3,figsize=(15,6),sharey=True)
r = sns.barplot(y='Official Time Minutes',x=win2015.index,data=win2015,palette='viridis',ax=ax[0])
annotate(ax=r,s="%.0f")
r.set_ylim([115,135]);
despine(rot=90)
r.set_title('Top 5 Marathon Finishers in 2015');
r1.set_ylabel('')
r1 = sns.barplot(y='Official Time Minutes',x=win2016.index,data=win2016,palette='viridis',ax=ax[1])
annotate(ax=r1,s="%.0f")
r1.set_ylim([115,135]);
despine(rot=90)
r1.set_title('Top 5 Marathon Finishers in 2016');

r2 = sns.barplot(y='Official Time Minutes',x=win2017.index,data=win2017,palette='viridis',ax=ax[2])
annotate(ax=r2,s="%.0f")
r2.set_ylim([115,135]);
despine(rot=90)
r2.set_title('Top 5 Marathon Finishers in 2017');

plt.setp(plt.gcf().get_axes(), xlabel='', ylabel='');
plt.setp(ax[0].xaxis.get_majorticklabels(), rotation=90);
plt.setp(ax[1].xaxis.get_majorticklabels(), rotation=90);

# %%
f,ax = plt.subplots(figsize=(16,8))
b = sns.boxenplot(data['Age'], data['Official Time Minutes'], palette="viridis")
b.set_title("Finish time in minutes distribution by age");
