# %%
import pandas as pd
from bq_helper import BigQueryHelper
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="D:\PycharmProjects\Stack-e63c482829a8.json"

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as plticker
import matplotlib
import warnings
from matplotlib import cm
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',100)
matplotlib.rcParams['font.family'] = "serif"
sns.set_style("white")
pd.options.display.float_format = "{:.2f}".format
pd.set_option('display.max_columns',100)

# %%
from google.cloud import bigquery
client = bigquery.Client()

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "openaq")

# %%
stackOverflow = BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="stackoverflow")

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "stackoverflow")
bq_assistant.list_tables()
# Out:
# ['badges',
#  'comments',
#  'post_history',
#  'post_links',
#  'posts_answers',
#  'posts_moderator_nomination',
#  'posts_orphaned_tag_wiki',
#  'posts_privilege_wiki',
#  'posts_questions',
#  'posts_tag_wiki',
#  'posts_tag_wiki_excerpt',
#  'posts_wiki_placeholder',
#  'stackoverflow_posts',
#  'tags',
#  'users',
#  'votes']

# %%
sqlA = '''
  SELECT
        EXTRACT(year from questions.creation_date) as Year,
        COUNT(distinct questions.id) as Number_of_Questions,
        COUNT(*) as Number_of_Answers
  FROM 
            `bigquery-public-data.stackoverflow.posts_questions` questions
  LEFT JOIN 
            `bigquery-public-data.stackoverflow.posts_answers` answers
  ON 
            questions.id = answers.parent_id
  WHERE 
            questions.tags like "%python%"
  GROUP BY 
          Year
  ORDER BY 
          1 ASC

'''

dfA = client.query(sqlA).to_dataframe()
dfA['Ratio'] = dfA['Number_of_Answers']/dfA['Number_of_Questions']

# %%
plt.figure(figsize=(16,4))
sns.lineplot(data=dfA.set_index('Year')[['Number_of_Questions','Number_of_Answers']],palette=['#FE938C','#3A506B'],linewidth=5).set_title('Liczba Pytan vs Liczba Odpowiedzi',fontsize=22)
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=True)
plt.xlabel('')
f,ax = plt.subplots(1,2,figsize=(15,5),sharey='row')
a1 = sns.barplot(y='Number_of_Questions',x='Year',data=dfA,palette=['#FE938C'],ax=ax[0])
a1.set(ylim=(0, 350000))
plt.xlabel('')
a2 = sns.barplot(y='Number_of_Answers',x='Year',data=dfA,palette=['#3A506B'],ax=ax[1])
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=True)
plt.xlabel('')
plt.figure(figsize=(16,4))
sns.lineplot(data=dfA.set_index('Year')['Ratio'],color='#79BD9A',linewidth=7).set_title('Ratio Odpowiedzi/Pytania')
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=True);
dfA
# Out:
#     Year  Number_of_Questions  Number_of_Answers  Ratio
# 0   2008                 2110              13299   6.30
# 1   2009                13233              51614   3.90
# 2   2010                27587              78554   2.85
# 3   2011                43163             102322   2.37
# 4   2012                66839             138032   2.07
# 5   2013               102302             185560   1.81
# 6   2014               124144             199875   1.61
# 7   2015               147906             230975   1.56
# 8   2016               174195             261004   1.50
# 9   2017               214549             309388   1.44
# 10  2018               257793             351367   1.36
# 11  2019                49690              65729   1.32

# %%
sql0 = '''

SELECT
EXTRACT(YEAR FROM creation_date) AS Year,
SUM(comment_count) AS Number_of_Comments,
SUM(view_count) AS Number_of_views,
COUNT(distinct id) Questions
FROM
  `bigquery-public-data.stackoverflow.posts_questions` WHERE tags like '%python%'
GROUP BY
  Year
HAVING
  Year >= 2008 AND Year <= 2019
ORDER BY Year; 

'''

df0 = client.query(sql0).to_dataframe()
df0['Comments Ratio'] = df0['Number_of_Comments']/df0['Questions']
df0['Views Ratio'] = df0['Number_of_views']/df0['Questions']

# %%
f,ax = plt.subplots(2,1,figsize=(15,8),sharex='col')
a3 = sns.lineplot(y=df0['Comments Ratio'],x=df0['Year'],data=df0,color='#FE938C',ax=ax[0],linewidth=5)
plt.xlabel('');
a4 = sns.lineplot(y=df0['Views Ratio'],x=df0['Year'],data=df0,color='#3A506B',ax=ax[1],linewidth=5)
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)
plt.suptitle('Komentarze/Pytania Ratio & Wizyty/Pytania Ratio',fontsize=22);
df0
# Out:
#     Year  Number_of_Comments  Number_of_views  Questions  Comments Ratio  \
# 0   2008                1973        130711100       2110            0.94
# 1   2009               15732        298286899      13233            1.19
# 2   2010               36650        326817106      27587            1.33
# 3   2011               67712        354604107      43163            1.57
# 4   2012              123609        388236696      66839            1.85
# 5   2013              201921        405400090     102302            1.97
# 6   2014              252660        262505914     124144            2.04
# 7   2015              320729        219049606     147906            2.17
# 8   2016              375513        178041882     174195            2.16
# 9   2017              476213        137608876     214549            2.22
# 10  2018              528169         48736199     257793            2.05
# 11  2019               97794          1998873      49690            1.97
#
#     Views Ratio
# 0      61948.39
# 1      22541.14
# 2      11846.78
# 3       8215.46
# 4       5808.54
# 5       3962.78
# 6       2114.53
# 7       1481.01
# 8       1022.08
# 9        641.39
# 10       189.05
# 11        40.23

# %%
sql2 = """
SELECT 
  EXTRACT(YEAR FROM creation_date) year, 
  IF(title LIKE '%?', 'with?', 'without') ends_with_question,
  ROUND(COUNT(accepted_answer_id )* 100/COUNT(*), 2) as answered 
FROM `bigquery-public-data.stackoverflow.posts_questions`
WHERE tags like '%python%'
GROUP BY 1,2
ORDER BY 1,2
"""



df2 = client.query(sql2).to_dataframe()

# %%
df2
# Out:
#     year ends_with_question  answered
# 0   2008              with?     83.68
# 1   2008            without     79.98
# 2   2009              with?     82.14
# 3   2009            without     77.73
# 4   2010              with?     78.49
# 5   2010            without     74.80
# 6   2011              with?     74.99
# 7   2011            without     71.19
# 8   2012              with?     73.05
# 9   2012            without     68.35
# 10  2013              with?     64.72
# 11  2013            without     62.34
# 12  2014              with?     60.83
# 13  2014            without     58.84
# 14  2015              with?     56.62
# 15  2015            without     54.84
# 16  2016              with?     54.30
# 17  2016            without     52.28
# 18  2017              with?     51.93
# 19  2017            without     50.43
# 20  2018              with?     44.75
# 21  2018            without     43.11
# 22  2019              with?     38.27
# 23  2019            without     37.10

# %%
plt.figure(figsize=(16,6))
sns.barplot(y='answered',x='year',data=df2,palette='cividis',hue='ends_with_question')
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)
plt.title('Procent odpowiedzi na pytania z pytajnikiem w tytule vs bez pytajnika"?" in title',fontsize=22);

# %%
sql3 = """SELECT 
  EXTRACT(YEAR FROM creation_date) year, 
  IF(title LIKE '%?', 'with?', 'without') ends_with_question,
  COUNT(*) as cnt
FROM `bigquery-public-data.stackoverflow.posts_questions`
WHERE tags like '%python%'
GROUP BY 1,2
ORDER BY 1,2
"""



df3 = client.query(sql3).to_dataframe()
df3
# Out:
#     year ends_with_question     cnt
# 0   2008              with?    1011
# 1   2008            without    1099
# 2   2009              with?    5051
# 3   2009            without    8182
# 4   2010              with?    8987
# 5   2010            without   18600
# 6   2011              with?   11889
# 7   2011            without   31274
# 8   2012              with?   15890
# 9   2012            without   50949
# 10  2013              with?   21372
# 11  2013            without   80930
# 12  2014              with?   24182
# 13  2014            without   99962
# 14  2015              with?   28827
# 15  2015            without  119079
# 16  2016              with?   33887
# 17  2016            without  140308
# 18  2017              with?   40836
# 19  2017            without  173713
# 20  2018              with?   47883
# 21  2018            without  209910
# 22  2019              with?   11569
# 23  2019            without   38121

# %%
plt.figure(figsize=(16,8))
sns.barplot(y='cnt',x='year',data=df3,palette='cividis',hue='ends_with_question')
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)
plt.title('Liczba pytan z "?" w tytule',fontsize=22);

# %%
sql4 = '''
    select 
    EXTRACT(YEAR FROM creation_date) year,
    count(distinct id) as questions, count(accepted_answer_id) as accepted_answers
    from `bigquery-public-data.stackoverflow.posts_questions`
    where 
    tags like '%python%'
    group by 1 order by 1 asc
'''
df4 = client.query(sql4).to_dataframe()
df4.set_index('year',inplace=True)

# %%
df4.plot(kind='bar',stacked=False,figsize=(15,6));
plt.title('Zaakceptowane Odpowiedzi vs Pytania - Python',fontsize=22);
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)

# %%
tags = '''
    select id, tags,EXTRACT(YEAR FROM creation_date) year
        from `bigquery-public-data.stackoverflow.posts_questions`
            where
            tags like '%python%'
'''
df5 = client.query(tags).to_dataframe()

df5.head()
# Out:
#        id                                   tags  year
# 0  169362                                 python  2008
# 1  378157               python|regex|postal-code  2008
# 2  240659           python|django|django-signals  2008
# 3  312096  python|stackless|python-stackless|mmo  2008
# 4  400739                                 python  2008

# %%
rows_list = []
for _, rows in df5.iterrows():
    tag = rows.tags.split('|')
    for t in tag:
        if t != 'python':
            row = {'question_id': rows.id, 'tag': t}
            rows_list.append(row)
tags_per_question = pd.DataFrame(rows_list)
tag_count = tags_per_question.groupby('tag').count().sort_values(by='question_id', ascending=False).rename(columns={'question_id':'counts'})
tag_count.head(30)
# Out:
#                    counts
# tag
# python-3.x         146659
# django             104119
# pandas              90291
# python-2.7          88895
# numpy               54233
# list                37596
# matplotlib          33539
# dictionary          26706
# regex               24627
# dataframe           24369
# tkinter             23275
# flask               22141
# tensorflow          21634
# string              19844
# csv                 19624
# arrays              18950
# json                17356
# selenium            14934
# beautifulsoup       13986
# html                13752
# google-app-engine   13113
# opencv              13008
# mysql               12923
# scipy               12263
# machine-learning    11947
# linux               11798
# scikit-learn        11574
# web-scraping        11237
# multithreading      11114
# sqlalchemy          11057

# %%
plt.figure(figsize=(16,8))
sns.barplot(x=tag_count.index[0:30], y=tag_count.counts[0:30],palette=['#3A506B']);
plt.xticks(rotation=90);
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)
plt.title('Najpopularniejsze tagi do pytan zwiazanych z Pythonem', fontsize=22);

# %%
df5['tags_count'] = df5['tags'].str.split('|').str.len()

# %%
tags_year = pd.DataFrame(df5.groupby(['year','tags_count'])['tags_count'].count()).rename(columns={'tags_count':'counts'}).reset_index()
tags_year.head()
# Out:
#    year  tags_count  counts
# 0  2008           1     116
# 1  2008           2     537
# 2  2008           3     710
# 3  2008           4     492
# 4  2008           5     255

# %%
plt.figure(figsize=(16,4))
g = sns.barplot(x=tags_year['year'], y=tags_year['counts'],palette='tab20b_r',hue=tags_year['tags_count'])
plt.xticks(rotation=90);
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)
plt.suptitle('Liczba tagów do pytan o Pythona', fontsize=18);
plt.figure(figsize=(16,2))
tags_all = pd.DataFrame(df5.groupby(['tags_count'])['tags_count'].count()).rename(columns={'tags_count':'counts'}).reset_index()
sns.barplot(x="counts", y="tags_count",
                data=tags_all, palette="muted",orient = 'h');
sns.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)

# %%
tags_all
# Out:
#    tags_count  counts
# 0           1   91239
# 1           2  310957
# 2           3  375789
# 3           4  266065
# 4           5  179436
# 5           6      25
