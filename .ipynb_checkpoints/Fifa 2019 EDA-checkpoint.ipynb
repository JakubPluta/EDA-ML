# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import matplotlib.ticker as plticker
import matplotlib
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',100)
matplotlib.rcParams['font.family'] = "serif"
sns.set_style("darkgrid")
from scipy import stats
from scipy.stats import norm
pd.options.display.float_format = "{:.2f}".format
pd.set_option('display.max_columns',100)
import re

# %%
fifa = pd.read_csv(f'Fifa\data.csv')
fifa.shape
# Out:
# (18207, 89)

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
# We have 18207 rows, and 89 columns in our dataset. I see that there are some nulls.

# %%
nulls = (fifa.isnull().sum()).sort_values(ascending=False).head(27)

# %%
null_colls = nulls.index.tolist()

# %%
fifa = fifa.drop(null_colls,axis=1)

# %%
fifa.shape
# Out:
# (18207, 62)

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
features = ['Name','Age','Nationality','Overall','Potential', 'Club', 'Value',
            'Wage','Preferred Foot','International Reputation','Weak Foot','Skill Moves','Work Rate',
            'Body Type','Position','Joined', 'Contract Valid Until','Height','Weight','Crossing', 
            'Finishing','HeadingAccuracy','ShortPassing', 'Volleys', 'Dribbling','Curve','FKAccuracy',
            'LongPassing','BallControl','Acceleration','SprintSpeed','Agility','Reactions', 'Balance',
            'ShotPower', 'Jumping','Stamina', 'Strength','LongShots','Aggression','Interceptions','Positioning', 
            'Vision', 'Penalties','Composure','Marking','StandingTackle', 'SlidingTackle','GKDiving',
            'GKHandling','GKKicking','GKPositioning','GKReflexes']

# %%
data = fifa[features]
data.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage Preferred Foot  \
# 0         FC Barcelona  €110.5M  €565K           Left
# 1             Juventus     €77M  €405K          Right
# 2  Paris Saint-Germain  €118.5M  €290K          Right
# 3    Manchester United     €72M  €260K          Right
# 4      Manchester City    €102M  €355K          Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 0                      5.00       4.00         4.00  Medium/ Medium
# 1                      5.00       4.00         5.00       High/ Low
# 2                      5.00       5.00         5.00    High/ Medium
# ...

# %%
data.shape
# Out:
# (18207, 53)

# %% [markdown]
# ### Exploration Data Analysis
# Goal: To explore what features make good player.

# %%
data.describe()
# Out:
#            Age  Overall  Potential  International Reputation  Weak Foot  \
# count 18207.00 18207.00   18207.00                  18159.00   18159.00
# mean     25.12    66.24      71.31                      1.11       2.95
# std       4.67     6.91       6.14                      0.39       0.66
# min      16.00    46.00      48.00                      1.00       1.00
# 25%      21.00    62.00      67.00                      1.00       3.00
# 50%      25.00    66.00      71.00                      1.00       3.00
# 75%      28.00    71.00      75.00                      1.00       3.00
# max      45.00    94.00      95.00                      5.00       5.00
#
#        Skill Moves  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# count     18159.00  18159.00   18159.00         18159.00      18159.00
# mean          2.36     49.73      45.55            52.30         58.69
# std           0.76     18.36      19.53            17.38         14.70
# ...

# %%
def get_desc(df,feature):
    print(df[feature].agg(['min','max','mean','std']))

# %% [markdown]
# ### Let's start with Age

# %%
muted_purp = sns.dark_palette("muted purple", input="xkcd")
bins0 = data['Age'].max() - data['Age'].min()
f, (box,hist) = plt.subplots(2,figsize=(12,8),sharex=False,gridspec_kw={"height_ratios": (.25, .85)})
sns.boxplot(data['Age'],ax=box,palette='inferno')
box.set_ylabel('')    
box.set_xlabel('')
box.xaxis.set_major_locator(plticker.MultipleLocator(1))
sns.distplot(data['Age'],bins=bins0,ax=hist,color='crimson', hist_kws=dict(alpha=0.69))
hist.xaxis.set_major_locator(plticker.MultipleLocator(1))
plt.suptitle('Players Age Histogram',fontsize=14);

# %%
get_desc(data,'Age')
# Out:
# min    16.00
# max    45.00
# mean   25.12
# std     4.67
# Name: Age, dtype: float64

# %% [markdown]
# After short analysis of player Age distribution We can see that average player age is 25. Most of player are 21-28 years old. Oldest player is 45 year old and youngest is 16 year old.

# %%
# 10 Eldest Players
(data[data['Age']>=28][['Name','Age','Club','Value','Overall']]).sort_values(by='Age',ascending=False).head(10)
# Out:
#                 Name  Age                          Club  Value  Overall
# 4741        O. Pérez   45                       Pachuca  €160K       71
# 18183  K. Pilkington   44              Cambridge United     €0       48
# 17726      T. Warner   44            Accrington Stanley     €0       53
# 10545    S. Narazaki   42                Nagoya Grampus   €40K       65
# 12192   H. Sulaimani   41                     Ohod Club     €0       63
# 15426       M. Tyler   41           Peterborough United   €10K       59
# 4228        B. Nivet   41                  ESTAC Troyes     €0       71
# 7225        C. Muñoz   41  CD Universidad de Concepción   €60K       68
# 1120       J. Villar   41                           NaN     €0       77
# 2821      S. Bertoli   40                     Patronato  €270K       73

# %%
# Youngest players
(data[data['Age']<21][['Name','Age','Club','Value','Overall']]).sort_values(by='Age',ascending=True).head(10)
# Out:
#                  Name  Age                      Club  Value  Overall
# 18206       G. Nugent   16           Tranmere Rovers   €60K       46
# 18162    T. Gundelund   16            Vejle Boldklub   €50K       48
# 17841  F. Tauchhammer   16            Wolfsberger AC   €90K       52
# 17354     L. D'Arrigo   16           Adelaide United  €130K       54
# 17808    A. Mahlonoko   16           Orlando Pirates  €100K       52
# 12496  Pelayo Morilla   16    Real Sporting de Gijón  €725K       63
# 17976       M. Larsen   16                Esbjerg fB   €70K       51
# 16927       B. Nygren   16              IFK Göteborg  €180K       56
# 16254       S. Steijn   16                 VVV-Venlo  €250K       58
# 17776  M. Köstenbauer   16  FC Admira Wacker Mödling   €90K       52

# %%
# We can see that 10 eldest player are after 40 year old, and 10 youngest players are 16 years old.

# %%
(data[(data['Age']>=21) & (data['Age']<=28)].shape[0])/(data['Age'].shape[0])*100
# 57% of players are in q1-q3 age. (21-28)
# Out:
# 57.24172021749876

# %%
players21_28 = (data[(data['Age']>=21) & (data['Age']<=28)])

# %%
ag = data.groupby('Age')['Age'].count()/data['Age'].count()

# %%
og = data.groupby('Overall')['Overall'].count()/data['Overall'].count()

# %%
f,ax = plt.subplots(1,2,figsize=(13,6))
sns.set_style("white")
sns.scatterplot(data=data, x='Age',y='Overall',palette='Blues',
                hue='Overall',alpha=0.79,marker='o',ax=ax[0]).set_title('Relation between Overall & Age')
sns.scatterplot(data=data, x='Age',y='Potential',palette='Reds',
                hue='Potential',alpha=0.79,marker='o',ax=ax[1]).set_title('Relation between Potential & Age');
plt.figure(figsize=(13,5))
sns.lineplot(x = 'Age', y = 'Overall', ci = None, data = data, label = 'Overall',c='b',linewidth=4)
sns.lineplot(x = 'Age', y = 'Potential', ci = None, data = data, label = 'Potential',c='r',linewidth=4)
plt.ylabel('Potential vs Overall')
plt.legend(loc = 1);

# %%
# Widać, że po zawodnicy osiągają swój potencjał do 30 roku życia. Później już tylko spada.

# %%
# Convert Wage and Values to number format!
# Find all digit numbers and add 000 at the end for K - > thousands
data['Wage'] = data['Wage'].apply(lambda x: int(re.findall('\d+', x)[0] + '000'))

# %%
data['Value'] = data['Value'].apply(lambda x: 'M' in x and int((re.findall('\d+\.*\d*', x)[0] 
                                                                + '000000').replace('.', '')) 
                                    or int((re.findall('\d+\.*\d*', x)[0] + '000').replace('.', '')))

# %%
data[['Value','Wage']].sample()
# Out:
#        Value  Wage
# 17602  70000  1000

# %%
rng = np.random.RandomState(0)
sizes = 100 * rng.rand(100)
f, ax = plt.subplots(figsize=(14,7))
im = ax.scatter(data['Value'], data['Overall'], c=np.clip(data['Overall'], 0, 120), 
                     cmap='twilight', alpha=.6, s=sizes)
ax.set_xlabel('Player Age')
ax.set_ylabel('Overall Points')
ax.set_title('Correlation between Overall Points and Age')
cbar = f.colorbar(im, ax=ax)
